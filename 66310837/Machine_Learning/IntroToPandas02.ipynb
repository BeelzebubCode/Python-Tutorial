# %% [markdown]
# # Introduction to Pandas for Beginners

# %% [markdown]
# ---

# %% [markdown]
# Pandas, a powerful library for data manipulation and analysis in Python.

# %% [markdown]
# Pandas provides data structures like Series and DataFrame to handle structured data efficiently.

# %% [markdown]
# ### Importing Pandas

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# ## Chapter 6: Data Transformation

# %%
# Sample DataFrame
df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Age': [25, 30, 35, 30, 45],
    'City': ['NY', 'LA', 'NY', 'LA', 'SF']
})
df
# Out:
#       Name  Age City
# 0    Alice   25   NY
# 1      Bob   30   LA
# 2  Charlie   35   NY
# 3    David   30   LA
# 4      Eve   45   SF

# %%
df['City'] = df['City'].replace({
    'NY': 'New York',
    'LA': 'Los Angeles',
    'SF': 'San Francisco'
})

df
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30    Los Angeles
# 2  Charlie   35       New York
# 3    David   30    Los Angeles
# 4      Eve   45  San Francisco

# %%
# Sample DataFrame with incorrect data
df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Age': [25, 30, -35, 40, -45],  # Age -35 is incorrect
    'City': ['New York', 'Los Angeles', 'New York', 'Los Angeles', 'San Francisco']
})
df
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30    Los Angeles
# 2  Charlie  -35       New York
# 3    David   40    Los Angeles
# 4      Eve  -45  San Francisco

# %%
df['Age'] = df['Age'].apply(lambda x: abs(x) if x < 0 else x)
df
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30    Los Angeles
# 2  Charlie   35       New York
# 3    David   40    Los Angeles
# 4      Eve   45  San Francisco

# %%
df = pd.read_csv('./data/breast_cancer_practice.csv')
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
df = df[['diagnosis', 'id', 'radius_mean', 'texture_mean', 'perimeter_mean',
         'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean']]

df
# Out:
#     diagnosis        id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M    842302        17.99         10.38          122.80     1001.0
# 1           M    842517        20.57         17.77          132.90     1326.0
# 2           M  84300903        19.69         21.25          130.00     1203.0
# 3           M  84348301        11.42         20.38           77.58      386.1
# 4           M  84358402        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 566         M    926424        21.56         22.39          142.00     1479.0
# 567         M    926682        20.13         28.25          131.20     1261.0
# 568         M    926954        16.60         28.08          108.30      858.1
# 569         M    927241        20.60         29.33          140.10     1265.0
# 570         B     92751         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean
# 0            0.11840           0.27760         0.30010
# 1            0.08474           0.07864         0.08690
# 2            0.10960           0.15990         0.19740
# 3            0.14250           0.28390         0.24140
# 4            0.10030           0.13280         0.19800
# ..               ...               ...             ...
# 566          0.11100           0.11590         0.24390
# 567          0.09780           0.10340         0.14400
# 568          0.08455           0.10230         0.09251
# 569          0.11780           0.27700         0.35140
# 570          0.05263           0.04362         0.00000
#
# [571 rows x 9 columns]

# %%
df = df.rename(columns={'compactness_mean': 'Compactness'})
df
# Out:
#     diagnosis        id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M    842302        17.99         10.38          122.80     1001.0
# 1           M    842517        20.57         17.77          132.90     1326.0
# 2           M  84300903        19.69         21.25          130.00     1203.0
# 3           M  84348301        11.42         20.38           77.58      386.1
# 4           M  84358402        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 566         M    926424        21.56         22.39          142.00     1479.0
# 567         M    926682        20.13         28.25          131.20     1261.0
# 568         M    926954        16.60         28.08          108.30      858.1
# 569         M    927241        20.60         29.33          140.10     1265.0
# 570         B     92751         7.76         24.54           47.92      181.0
#
#      smoothness_mean  Compactness  concavity_mean
# 0            0.11840      0.27760         0.30010
# 1            0.08474      0.07864         0.08690
# 2            0.10960      0.15990         0.19740
# 3            0.14250      0.28390         0.24140
# 4            0.10030      0.13280         0.19800
# ..               ...          ...             ...
# 566          0.11100      0.11590         0.24390
# 567          0.09780      0.10340         0.14400
# 568          0.08455      0.10230         0.09251
# 569          0.11780      0.27700         0.35140
# 570          0.05263      0.04362         0.00000
#
# [571 rows x 9 columns]

# %%
df['radius_mean'] = np.ceil(df['radius_mean']).astype(int)
df
# Out:
#     diagnosis        id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M    842302           18         10.38          122.80     1001.0
# 1           M    842517           21         17.77          132.90     1326.0
# 2           M  84300903           20         21.25          130.00     1203.0
# 3           M  84348301           12         20.38           77.58      386.1
# 4           M  84358402           21         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 566         M    926424           22         22.39          142.00     1479.0
# 567         M    926682           21         28.25          131.20     1261.0
# 568         M    926954           17         28.08          108.30      858.1
# 569         M    927241           21         29.33          140.10     1265.0
# 570         B     92751            8         24.54           47.92      181.0
#
#      smoothness_mean  Compactness  concavity_mean
# 0            0.11840      0.27760         0.30010
# 1            0.08474      0.07864         0.08690
# 2            0.10960      0.15990         0.19740
# 3            0.14250      0.28390         0.24140
# 4            0.10030      0.13280         0.19800
# ..               ...          ...             ...
# 566          0.11100      0.11590         0.24390
# 567          0.09780      0.10340         0.14400
# 568          0.08455      0.10230         0.09251
# 569          0.11780      0.27700         0.35140
# 570          0.05263      0.04362         0.00000
#
# [571 rows x 9 columns]

# %%
df['radius_mean'] = df['radius_mean'] + 1
df
# Out:
#     diagnosis        id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M    842302           19         10.38          122.80     1001.0
# 1           M    842517           22         17.77          132.90     1326.0
# 2           M  84300903           21         21.25          130.00     1203.0
# 3           M  84348301           13         20.38           77.58      386.1
# 4           M  84358402           22         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 566         M    926424           23         22.39          142.00     1479.0
# 567         M    926682           22         28.25          131.20     1261.0
# 568         M    926954           18         28.08          108.30      858.1
# 569         M    927241           22         29.33          140.10     1265.0
# 570         B     92751            9         24.54           47.92      181.0
#
#      smoothness_mean  Compactness  concavity_mean
# 0            0.11840      0.27760         0.30010
# 1            0.08474      0.07864         0.08690
# 2            0.10960      0.15990         0.19740
# 3            0.14250      0.28390         0.24140
# 4            0.10030      0.13280         0.19800
# ..               ...          ...             ...
# 566          0.11100      0.11590         0.24390
# 567          0.09780      0.10340         0.14400
# 568          0.08455      0.10230         0.09251
# 569          0.11780      0.27700         0.35140
# 570          0.05263      0.04362         0.00000
#
# [571 rows x 9 columns]

# %%
data = {'Name': ['John', 'Anna', 'Peter'], 'Age': [28, 24, 35]}
data = pd.DataFrame(data)
data['Cumulative_sum'] = data['Age'].cumsum()
data
# Out:
#     Name  Age  Cumulative_sum
# 0   John   28              28
# 1   Anna   24              52
# 2  Peter   35              87

# %%
# replace_M = {
#     'M': 'Malignant',
#     'B': 'Benign'
# }
# df['diagnosis'] = df['diagnosis'].replace(replace_M)

df['diagnosis_full'] = df['diagnosis'].apply(lambda x: "Malignant" if x == "M" else "Benign")
df
# Out:
#     diagnosis        id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M    842302           19         10.38          122.80     1001.0
# 1           M    842517           22         17.77          132.90     1326.0
# 2           M  84300903           21         21.25          130.00     1203.0
# 3           M  84348301           13         20.38           77.58      386.1
# 4           M  84358402           22         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 566         M    926424           23         22.39          142.00     1479.0
# 567         M    926682           22         28.25          131.20     1261.0
# 568         M    926954           18         28.08          108.30      858.1
# 569         M    927241           22         29.33          140.10     1265.0
# 570         B     92751            9         24.54           47.92      181.0
#
#      smoothness_mean  Compactness  concavity_mean diagnosis_full
# 0            0.11840      0.27760         0.30010      Malignant
# 1            0.08474      0.07864         0.08690      Malignant
# 2            0.10960      0.15990         0.19740      Malignant
# 3            0.14250      0.28390         0.24140      Malignant
# 4            0.10030      0.13280         0.19800      Malignant
# ..               ...          ...             ...            ...
# 566          0.11100      0.11590         0.24390      Malignant
# 567          0.09780      0.10340         0.14400      Malignant
# 568          0.08455      0.10230         0.09251      Malignant
# 569          0.11780      0.27700         0.35140      Malignant
# 570          0.05263      0.04362         0.00000         Benign
#
# [571 rows x 10 columns]

# %% [markdown]
# ## Chapter 7: Grouping and Aggregation

# %% [markdown]
# ## Chapter 8: Merging and Joining

# %%
# Merging data
data1 = {'ID': [1, 2, 3], 'Name': ['Alice', 'Bob', 'Charlie']}
data2 = {'ID': [1, 2, 3], 'Score': [85, 90, 95]}
df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

# %%
# Concatenating data
data1 = {'ID': [1, 2, 3], 'Name': ['Alice', 'Bob', 'Charlie']}
data2 = {'ID': [4, 5, 6], 'Name': ['John', 'Ellie', 'Will']}
df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

# %% [markdown]
# ## Chapter 9: Save data
